# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# MERGING THE DATASETS

# %%
df1 = pd.read_csv("C:\\Users\\ABHAS\\Downloads\\emotion_data-20230925T172204Z-001\\emotion_data\\1\\emotion.csv")

# %%
df1.head()
# Out:
#                                movie_id  image_seq     angry   disgust  \
# 0  93663f94-bf0a-4ce8-a29a-a5236cc7fe6a          0   4.31735  0.000594
# 1  93663f94-bf0a-4ce8-a29a-a5236cc7fe6a          1  53.22530  2.981640
# 2  93663f94-bf0a-4ce8-a29a-a5236cc7fe6a          2   8.79651  0.029468
# 3  93663f94-bf0a-4ce8-a29a-a5236cc7fe6a          3   9.45303  0.106778
# 4  93663f94-bf0a-4ce8-a29a-a5236cc7fe6a          4  56.00020  0.000004
#
#         fear     happy        sad   surprise   neutral dominant_emotion
# 0   2.879790   1.65035   2.779980   0.600814  87.77110          neutral
# 1  12.736800   1.52347   1.051320  27.216800   1.26462            angry
# 2   2.968160  16.83150  39.884600   0.279335  31.21050              sad
# 3   1.553080  20.93010   3.503870   0.909426  63.54370          neutral
# 4   0.162231   5.58358   0.197026  12.807600  25.24940            angry

# %%
df1 = df1.merge(pd.read_csv("C:\\Users\\ABHAS\\Downloads\\emotion_data-20230925T172204Z-001\\emotion_data\\1\\gaze.csv",usecols=['gaze','blink','eye_offset']),right_index=True,left_index=True)

# %%
df2 = pd.read_csv("C:\\Users\\ABHAS\\Downloads\\emotion_data-20230925T172204Z-001\\emotion_data\\2\\emotion.csv")

# %%
df2 = df2.merge(pd.read_csv("C:\\Users\\ABHAS\\Downloads\\emotion_data-20230925T172204Z-001\\emotion_data\\2\\gaze.csv", usecols=['gaze','blink','eye_offset']),right_index=True,left_index=True)

# %%
df3 = pd.read_csv("C:\\Users\\ABHAS\\Downloads\\emotion_data-20230925T172204Z-001\\emotion_data\\3\\emotion.csv")

# %%
df3 = df3.merge(pd.read_csv("C:\\Users\\ABHAS\\Downloads\\emotion_data-20230925T172204Z-001\\emotion_data\\3\\gaze.csv", usecols=['gaze','blink','eye_offset']),right_index=True,left_index=True)

# %%
df4 = pd.read_csv("C:\\Users\\ABHAS\\Downloads\\emotion_data-20230925T172204Z-001\\emotion_data\\4\\emotion.csv")

# %%
df4 = df4.merge(pd.read_csv("C:\\Users\\ABHAS\\Downloads\\emotion_data-20230925T172204Z-001\\emotion_data\\4\\gaze.csv", usecols=['gaze','blink','eye_offset']),right_index=True,left_index=True)

# %%
df5 = pd.read_csv("C:\\Users\\ABHAS\\Downloads\\emotion_data-20230925T172204Z-001\\emotion_data\\5\\emotion.csv")

# %%
df5 = df5.merge(pd.read_csv("C:\\Users\\ABHAS\\Downloads\\emotion_data-20230925T172204Z-001\\emotion_data\\5\\gaze.csv", usecols=['gaze','blink','eye_offset']),right_index=True,left_index=True)

# %%
df6 = pd.read_csv("C:\\Users\\ABHAS\\Downloads\\emotion_data-20230925T172204Z-001\\emotion_data\\6\\emotion.csv")

# %%
df6 = df6.merge(pd.read_csv("C:\\Users\\ABHAS\\Downloads\\emotion_data-20230925T172204Z-001\\emotion_data\\6\\gaze.csv", usecols=['gaze','blink','eye_offset']),right_index=True,left_index=True)

# %%
df7 = pd.read_csv("C:\\Users\\ABHAS\\Downloads\\emotion_data-20230925T172204Z-001\\emotion_data\\7\\emotion.csv")

# %%
df7 = df7.merge(pd.read_csv("C:\\Users\\ABHAS\\Downloads\\emotion_data-20230925T172204Z-001\\emotion_data\\7\\gaze.csv", usecols=['gaze','blink','eye_offset']),right_index=True,left_index=True)

# %%
df8 = pd.read_csv("C:\\Users\\ABHAS\\Downloads\\emotion_data-20230925T172204Z-001\\emotion_data\\9\\emotion.csv")

# %%
df8 = df8.merge(pd.read_csv("C:\\Users\\ABHAS\\Downloads\\emotion_data-20230925T172204Z-001\\emotion_data\\8\\gaze.csv", usecols=['gaze','blink','eye_offset']),right_index=True,left_index=True)

# %%
df9 = pd.read_csv("C:\\Users\\ABHAS\\Downloads\\emotion_data-20230925T172204Z-001\\emotion_data\\9\\emotion.csv")

# %%
df9 = df9.merge(pd.read_csv("C:\\Users\\ABHAS\\Downloads\\emotion_data-20230925T172204Z-001\\emotion_data\\9\\gaze.csv", usecols=['gaze','blink','eye_offset']),right_index=True,left_index=True)

# %%
df10 = pd.read_csv("C:\\Users\\ABHAS\\Downloads\\emotion_data-20230925T172204Z-001\\emotion_data\\10\\emotion.csv")

# %%
df10 = df10.merge(pd.read_csv("C:\\Users\\ABHAS\\Downloads\\emotion_data-20230925T172204Z-001\\emotion_data\\10\\gaze.csv", usecols=['gaze','blink','eye_offset']),right_index=True,left_index=True)

# %% [markdown]
# Function to check for Non null values

# %%
def inf(data):
    print(data.info())
    # print(data.describe())

# %%
l =  [df1,df2,df3,df4,df5,df6,df7,df8,df9,df10]

# %%
for i in l:
    inf(i)
    print()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 87 entries, 0 to 86
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   movie_id          87 non-null     object
#  1   image_seq         87 non-null     int64
#  2   angry             87 non-null     float64
#  3   disgust           87 non-null     float64
#  4   fear              87 non-null     float64
#  5   happy             87 non-null     float64
#  6   sad               87 non-null     float64
#  7   surprise          87 non-null     float64
#  8   neutral           87 non-null     float64
#  9   dominant_emotion  87 non-null     object
#  10  gaze              87 non-null     int64
#  11  blink             87 non-null     int64
#  12  eye_offset        87 non-null     float64
# dtypes: float64(8), int64(3), object(2)
# memory usage: 9.5+ KB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# ...

# %% [markdown]
# Funtion for the descripton of the data, it's mean, median, quantile range, etc.

# %%
def des(data):
    print(data.describe())

# %%
des(df1)
# Out:
#        image_seq      angry       disgust       fear      happy        sad  \
# count  87.000000  87.000000  8.700000e+01  87.000000  87.000000  87.000000
# mean   45.390805  14.451059  6.168965e-01  18.382797   5.865318  13.575324
# std    27.587643  18.544205  2.679399e+00  25.073562  11.237819  19.787221
# min     0.000000   0.164384  2.400910e-10   0.079219   0.000005   0.000073
# 25%    22.500000   1.867450  8.769180e-05   1.862945   0.143215   1.845405
# 50%    44.000000   6.412790  3.443590e-03   6.366870   1.476330   5.578010
# 75%    68.500000  18.765500  6.486260e-02  21.010100   5.569355  14.056700
# max    94.000000  71.172500  2.150890e+01  94.981800  66.222300  91.563600
#
#         surprise    neutral       gaze  blink  eye_offset
# count  87.000000  87.000000  87.000000   87.0   87.000000
# mean    8.744969  38.363648   0.620690    0.0   15.711706
# std    19.621163  33.468718   0.488028    0.0   17.942114
# min     0.000008   0.000117   0.000000    0.0  -33.465500
# ...

# %%
des(df2)
# Out:
#        image_seq      angry       disgust       fear      happy        sad  \
# count  87.000000  87.000000  8.700000e+01  87.000000  87.000000  87.000000
# mean   43.000000  10.395041  3.918153e-01   6.747536  35.063288  18.558391
# std    25.258662  22.483989  1.555114e+00  13.716758  40.139694  23.306587
# min     0.000000   0.000015  2.198970e-10   0.000002   0.011498   0.005248
# 25%    21.500000   0.098704  2.648140e-06   0.159929   1.595905   1.525660
# 50%    43.000000   0.965159  5.163640e-04   1.824250  11.561100   7.884060
# 75%    64.500000   6.389125  8.824245e-02   4.961165  80.356200  29.037500
# max    86.000000  95.056300  1.270010e+01  82.107700  99.981800  97.396900
#
#            surprise    neutral       gaze      blink  eye_offset
# count  8.700000e+01  87.000000  87.000000  87.000000   87.000000
# mean   2.267330e+00  26.576600   0.609195   0.045977   21.768546
# std    1.140703e+01  38.906958   0.490759   0.210649   15.619435
# ...

# %%
from sklearn.preprocessing import StandardScaler
from scipy import stats

# %%
sns.displot(df1['angry'],kind = 'kde')

# %%
fig, ax = plt.subplots(1, 2)
sns.distplot(df1[columns_used], hist = True, kde = True,
            kde_kws = {'shade': True, 'linewidth': 2},
            label = "Non-Normal", color ="green", ax = ax[0])
fitted_data, fitted_lambda = stats.boxcox(df1['happy'])
sns.distplot(fitted_data, hist = True, kde = True,
            kde_kws = {'shade': True, 'linewidth': 2},
            label = "Normal", color ="blue", ax = ax[1])
# Out:
# C:\Users\ABHAS\AppData\Local\Temp\ipykernel_16356\3082926494.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1[columns_used], hist = True, kde = True,
# c:\Users\ABHAS\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\distributions.py:2511: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)
# C:\Users\ABHAS\AppData\Local\Temp\ipykernel_16356\3082926494.py:6: UserWarning:
#
# ...

# %%
happy = pd.DataFrame((df1['happy'],df2['happy'],df3['happy'],df4['happy'],df5['happy'],df6['happy'],df7['happy'],df8['happy'],df9['happy'],df10['happy']),columns=[i for i in range(1,11)])
happy.dropna(axis=0)
# happy.shape
# Out:
#               1          2          3          4          5          6   \
# happy   1.523470  16.831500  20.930100   5.583580   0.003218   0.134349
# happy  93.566400  42.703800  16.536800  98.518100   0.394626   0.146963
# happy  28.611900   9.798490   6.152380  56.512500   1.093410  21.733100
# happy   0.113288   0.000082   0.006685   0.207840   0.019350   0.001846
# happy  36.945200  37.139300  11.044200  11.038800  33.953200  11.567000
# happy   0.103848   0.285020  99.408400   0.001237  99.748600  23.794200
# happy  76.190600  71.409600  14.193200   0.365306  55.082000   0.312699
# happy  76.190600  71.409600  14.193200   0.365306  55.082000   0.312699
# happy  97.453700   0.283289   0.007699   3.834700   4.486830   0.056474
#
#               7          8          9          10
# happy   5.555130  10.238000   0.185183   1.468250
# happy  55.061100   0.440017  77.896100   1.287480
# happy  95.781900  65.745800   5.780110  25.613500
# ...

# %%
sns.barplot(x = happy.median().index,y = happy.median().values)
plt.xlabel('candidate number')
plt.title('happiness emotion')
# Out:
# Text(0.5, 1.0, 'happiness emotion')

# %%
angry = pd.DataFrame((df1['angry'],df2['angry'],df3['angry'],df4['angry'],df5['angry'],df6['angry'],df7['angry'],
                      df8['angry'],df9['angry'],df10['angry']),columns=[i for i in range(1,11)])
angry.dropna(axis=0)
# angry.shape
# Out:
#               1          2          3          4         5          6   \
# angry  53.225300   8.796510   9.453030  56.000200  0.635349   6.412790
# angry   0.179621  10.126300  37.344900   0.003088  0.442753   1.656520
# angry   0.016925   0.095944   1.411020   1.127490  0.491866   0.563820
# angry   0.273406   0.087041   2.452160   0.181937  0.295551   1.414990
# angry   0.001332   0.001311   0.001810   0.001834  0.000589   0.002022
# angry   6.587830   5.066870   0.000539   0.000672  0.000485   0.020170
# angry   2.081140   9.438360   4.378860   0.001452  8.254360  15.924600
# angry   2.081140   9.438360   4.378860   0.001452  8.254360  15.924600
# angry   0.099217   0.430551  11.622700   1.428140  0.441355   0.164250
#
#               7          8          9          10
# angry  29.813200  22.616900   3.738570  11.488100
# angry   0.106536   0.449587   1.371880   2.067890
# angry   0.313804   3.514000   0.050098   0.172233
# angry   3.248430   1.282790   0.013294   4.140390
# ...

# %%
lis1 = angry.mean()
lis1.values
# Out:
# array([ 6.46510372,  4.35137122,  7.10501326,  6.52736266,  2.09074081,
#         4.67597354,  5.72614304,  3.88455748,  3.80743633, 14.14832405])

# %%
plt.title('angry emotion')
plt.xlabel('candidate number')
sns.barplot(x = angry.median().index,y = angry.median().values)
# Out:
# <Axes: title={'center': 'angry emotion'}, xlabel='candidate number'>

# %% [markdown]
# EDA

# %% [markdown]
# Funtion for plotting the histplot for different datasets

# %%
def plotting(data,i):
    # Countplot for dominant emotions
    sns.histplot(data=data, x='dominant_emotion')
    plt.title(f'Distribution of Dominant Emotions in candidate {i}')
    plt.show()

# %%
# Boxplots to visualize emotion distributions
def plot1(data,i):
    plt.figure(figsize=(12, 6))
    sns.boxplot(data=data[['neutral', 'angry', 'sad', 'fear', 'surprise', 'happy']], palette='Set2')
    plt.title(f'Distribution of Emotion Percentages{i}')
    plt.xticks(rotation=45)
    plt.show()

# %%
columns_used = ['neutral','angry','sad','fear','surprise','happy']

# %%
count = 0
for i in l:
    count += 1
    plot1(i,count)

# %% [markdown]
# Removing Outliers from data

# %%
import numpy as np

# Assuming 'data' is your dataset with columns containing outliers
# Define a function to remove outliers using IQR
def remove_outliers_iqr(data, threshold=1.5):
    # Calculate the first quartile (Q1) and third quartile (Q3) for each column
    data = data[columns_used]
    Q1 = data.quantile(0.25)
    Q3 = data.quantile(0.75)
    
    # Calculate the IQR for each column
    IQR = Q3 - Q1
    
    # Define the lower and upper bounds to identify outliers
    lower_bound = Q1 - threshold * IQR
    upper_bound = Q3 + threshold * IQR
    
    # Create a mask to identify rows with outliers in any column
    outlier_mask = ((data < lower_bound) | (data > upper_bound)).any(axis=1)

    data_imputed = data.copy()
    for column in data.columns:
        median = data[column].median()
        data_imputed.loc[outlier_mask, column] = median
    
    # Remove rows with outliers
    data_cleaned = data[~outlier_mask]
    
    return data_cleaned

# Usage example:
# Assuming 'your_data' is your dataset with columns containing outliers
# df1_remove_outlier = remove_outliers_iqr(df4

# %%
df1_new = remove_outliers_iqr(df1).merge(df1['dominant_emotion'],left_index=True,right_index=True)
df2_new = remove_outliers_iqr(df2).merge(df2['dominant_emotion'],left_index=True,right_index=True)
df3_new = remove_outliers_iqr(df3).merge(df3['dominant_emotion'],left_index=True,right_index=True)
df4_new = remove_outliers_iqr(df4).merge(df4['dominant_emotion'],left_index=True,right_index=True)
df5_new = remove_outliers_iqr(df5).merge(df5['dominant_emotion'],left_index=True,right_index=True)
df6_new = remove_outliers_iqr(df6).merge(df6['dominant_emotion'],left_index=True,right_index=True)
df7_new = remove_outliers_iqr(df7).merge(df7['dominant_emotion'],left_index=True,right_index=True)
df8_new = remove_outliers_iqr(df8).merge(df8['dominant_emotion'],left_index=True,right_index=True)
df9_new = remove_outliers_iqr(df9).merge(df9['dominant_emotion'],left_index=True,right_index=True)
df10_new = remove_outliers_iqr(df10).merge(df10['dominant_emotion'],left_index=True,right_index=True)
l_new = [df1_new,df2_new,df3_new,df4_new,df5_new,df6_new,df7_new,df8_new,df9_new,df10_new]

# %% [markdown]
# Removed/supressed outliers

# %%
count = 0
for i in l_new:
    count += 1
    plot1(i,count)

# %%
df7.head()
# Out:
#                                movie_id  image_seq     angry       disgust  \
# 0  6539370c-256e-4ed2-9d00-1be1f051163f          0  0.011716  2.442630e-03
# 1  6539370c-256e-4ed2-9d00-1be1f051163f          1  6.587830  2.033840e-02
# 2  6539370c-256e-4ed2-9d00-1be1f051163f          2  5.066870  7.610640e-05
# 3  6539370c-256e-4ed2-9d00-1be1f051163f          3  0.000539  1.678270e-05
# 4  6539370c-256e-4ed2-9d00-1be1f051163f          4  0.000672  1.765070e-09
#
#         fear      happy        sad   surprise       neutral dominant_emotion  \
# 0   0.350391  93.426900   4.564420   0.016044  1.628070e+00            happy
# 1  35.106600   0.103848  38.967200   0.001294  1.921290e+01              sad
# 2   1.008420   0.285020  29.728900   0.000373  6.391040e+01          neutral
# 3   0.041162  99.408400   0.239465   0.067905  2.425000e-01            happy
# 4   4.977040   0.001237   0.000022  95.021000  7.548270e-07         surprise
#
#    gaze  blink  eye_offset
# ...

# %%
count = 0
for i in l:
    count += 1
    plotting(i,count)

# %%
sns.countplot(data=df4, x='dominant_emotion')
plt.title('Distribution of Dominant Emotions in candidate ')
plt.show()

# %% [markdown]
# Offset Analysis

# %%
def offset_analysis(data,count):    
    sns.boxplot(y = data['eye_offset'],x = data['dominant_emotion'])
    plt.title(f'Eyes Offset barplot in candidate {count}')
    plt.show()

# %%
count = 0
for i in l:
    count+=1
    offset_analysis(i,count)

# %%
count = 0
for i in l:
    count+=1
    offset_analysis(i,count)

# %%
sns.lineplot(y = df1['eye_offset'],x=df1['sad'])
# Out:
# <Axes: xlabel='sad', ylabel='eye_offset'>

# %%
sns.lineplot(y = df1['eye_offset'],x=df1['angry'])
# Out:
# <Axes: xlabel='angry', ylabel='eye_offset'>
